# %%
from hdrh.histogram import HdrHistogram
import seaborn as sns
import pandas
from matplotlib import pyplot as plt
import os.path
from enum import Enum
import matplotlib as mpl
from typing import *

# %% [markdown]
# To generate the dumps, do something like this
# ```fish
# for GC in Serial Parallel G1 Z Shenandoah; taskset -c 0-7 /usr/lib/jvm/temurin-17-amd64/bin/java -server -XX:-TieredCompilation -Xcomp -XX:+UnlockExperimentalVMOptions -XX:+Use{$GC}GC -XX:ConcGCThreads=4 -XX:ParallelGCThreads=4 -Xms420M -Xmx420M -jar /usr/share/benchmarks/dacapo/dacapo-evaluation-git-29a657f.jar -n 5 lusearch -t 4 --dump-latency; mv scratch scratch-$GC; end
# ```

# %%
RUNID = 'fox-2022-03-15-Tue-122906'
HFAC = 3023
HEAP = {
    'lusearch': 70,
    'cassandra': 269,
    'h2':  3489,
    'tomcat': 76,
}
DACAPO = 'dacapochopin-29a657f'


# SAVE_FILE = 'pdf'
# SAVE_FILE = 'jpg'
SAVE_FILE = None


DATA = {
    'LXR': '{runid}/{bench}.{hfac}.{heap}.jdk-lxr.ix.common.tph.nr-1.{dacapo}',
}
MAX_INVOCATIONS = 40
MIN_LATENCY_USEC = 1
MAX_LATENCY_USEC = 1000 * 1000 # 1 sec
LATENCY_SIGNIFICANT_DIGITS = 5

# %%
def load_data(invocation: int, folder: str):
    path = os.path.realpath(os.path.expanduser('{}.{}/_pauses.csv'.format(folder, invocation)))
    if not os.path.isfile(path):
        return None
    df =  pandas.read_csv(path)
    df["millis"] = df["nanos"] / 1000000
    return df

def load_data_and_plot(bench, data: Optional[Dict[str, Union[str, List[str]]]] = None, invocations = MAX_INVOCATIONS, save = SAVE_FILE):
    assert bench in HEAP
    print(f'[{bench}] Loading...')
    histograms = {}
    # Clean up inputs
    if data is None:
        data = { k: v for k, v in DATA.items() }
    for gc in data.keys():
        if isinstance(data[gc], str):
            data[gc] = [ data[gc] ]
        data[gc] = [
            f'~/MMTk-Dev/evaluation/results/log/{x}'.format(runid=RUNID, bench=bench, hfac=HFAC, heap=HEAP[bench], dacapo=DACAPO)
            for x in data[gc]
        ]
    data: Dict[str, List[str]]
    # Load data
    for gc, logs in data.items():
        histograms[gc] = []
        for folder in logs:
            for i in range(invocations):
                loaded_data = load_data(i, folder)
                if loaded_data is None:
                    continue
                histogram = HdrHistogram(MIN_LATENCY_USEC, MAX_LATENCY_USEC, LATENCY_SIGNIFICANT_DIGITS)
                latencies = loaded_data["millis"]
                for l in latencies:
                    histogram.record_value(l)
                histograms[gc].append(histogram)
    # Process data
    print(f'[{bench}] Processing...')
    percentile_list = []
    for gc, hists in histograms.items():
        for j, histogram in enumerate(hists):
            for i in histogram.get_percentile_iterator(5):
                percentile_list.append({"GC": gc, "inv": j, "value": i.value_iterated_to, "percentile": i.percentile_level_iterated_to / 100})
    percentile_df = pandas.DataFrame(percentile_list)
    percentile_df["other"] = 1 / (1 - percentile_df["percentile"])
    # Plot curves
    print(f'[{bench}] Plotting...')
    fig, ax = plt.subplots(1,1,figsize=(16,12))
    # fig.suptitle(f'{bench} {latency_type} latency')
    sns.color_palette()
    # colors = ['green', 'blue', 'orange', 'red'][:len(gcs)]
    # print(f'{gcs} {colors}')
    sns.lineplot(data=percentile_df, x="other", y="value", hue="GC")
    # sns.lineplot(data=percentile_df, x="other", y="value", hue="GC")
    ax.set_xscale('log')
    ax.set_xlabel('Percentile', fontsize=26, labelpad=12)
    ax.set_ylabel('Pause time (msec)', fontsize=26, labelpad=12)
    ax.set_xticks([1, 10, 100, 1000, 10000, 100000, 1000000])
    ax.set_xticklabels(['0', '90', '99', '99.9', '99.99', '99.999', '99.9999'], fontsize=20)
    plt.yticks(fontsize=20)
    ax.yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, pos: f'{x}'.format(x)))
    plt.legend(fontsize=26)

    if save is not None:
        print(f'[{bench}] Save to pauses-{bench}.{save}')
        plt.savefig(f'pauses-{bench}.{save}', bbox_inches='tight')

# %% [markdown]
# # lusearch

# %%
load_data_and_plot(bench = 'lusearch')
# Out:
# [lusearch] Loading...
# [lusearch] Processing...
# [lusearch] Plotting...

# %% [markdown]
# # cassandra

# %%
load_data_and_plot(bench = 'cassandra')
# Out:
# [cassandra] Loading...
# [cassandra] Processing...
# [cassandra] Plotting...

# %% [markdown]
# # h2

# %%
load_data_and_plot(bench = 'h2')
# Out:
# [h2] Loading...
# [h2] Processing...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'percentile'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-8fd2d3a87e2e> in <module>
# ----> 1 load_data_and_plot(bench = 'h2')
#
# <ipython-input-3-24b1c7b9028c> in load_data_and_plot(bench, data, invocations, save, latency_type)
#      43                 percentile_list.append({"GC": gc, "inv": j, "value": i.value_iterated_to, "percentile": i.percentile_level_iterated_to / 100})
#      44     percentile_df = pandas.DataFrame(percentile_list)
# ---> 45     percentile_df["other"] = 1 / (1 - percentile_df["percentile"])
#      46     # Plot curves
#      47     print(f'[{bench}] Plotting...')
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'percentile'

# %% [markdown]
# # tomcat

# %%
load_data_and_plot(bench = 'tomcat')
